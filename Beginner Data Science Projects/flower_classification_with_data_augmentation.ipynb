# %%
# imports
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras import utils
utils.set_random_seed(18)

# %%
# loading data
(train_ds, val_ds, test_ds), info = tfds.load('tf_flowers', split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'], 
                                              with_info=True, as_supervised=True)

# %%
# getting number of classes
num_cls = info.features['label'].num_classes
print(num_cls)
# Out:
# 5

# %%
# getting class names 
info.features['label'].names
# Out:
# ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']

# %%
# looking at some images
fig = tfds.show_examples(train_ds, info, rows=1, cols=5)

# %%
# preprocessing images
def resize_rescale(image, label):
  image = tf.image.resize(image, (256, 256))
  image = (image / 255.0)
  return image, label
train_ds = train_ds.map(resize_rescale)
val_ds = val_ds.map(resize_rescale)
test_ds = test_ds.map(resize_rescale)

# %%
# fetching an image for data augmentation
get_label_name = info.features['label'].int2str
image, label = next(iter(train_ds))
_ = plt.imshow(image)
_ = plt.title(get_label_name(label))

# %%
# defining a function to visualize augmented images
def visualize(original, augmented):
  fig = plt.figure()
  plt.subplot(1,2,1)
  plt.title('Original image')
  plt.imshow(original)
  plt.subplot(1,2,2)
  plt.title('Augmented image')
  plt.imshow(augmented)

# %%
# random hue transformation
for i in range(4):
  augmented_image = tf.image.random_hue(image, max_delta=0.5, seed=42)
  visualize(image, augmented_image)

# %%
# random brightness transformation
for i in range(4):
  augmented_image = tf.image.random_brightness(image=image, max_delta=0.5, seed=42)
  visualize(image, tf.clip_by_value(augmented_image, 0, 1))

# %%
# horizontal flip transformation
for i in range(4):
  augmented_image = tf.image.random_flip_left_right(image, seed=42)
  visualize(image, augmented_image)

# %% [markdown]
# **For checking image transformations individually:**
# ```
# # fetching an image for data augmentation
# get_label_name = info.features['label'].int2str
# image, label = next(iter(train_ds))
# _ = plt.imshow(image)
# _ = plt.title(get_label_name(label))
#
# # defining a function to visualize augmented images
# def visualize(original, augmented):
#   fig = plt.figure()
#   plt.subplot(1,2,1)
#   plt.title('Original image')
#   plt.imshow(original)
#   plt.subplot(1,2,2)
#   plt.title('Augmented image')
#   plt.imshow(augmented)
#
# # applying tf.image function on the image
# flipped = tf.image.random_flip_left_right(image, seed=20)
# visualize(image, flipped)
# ```

# %%
# defining a function to apply the above transformations on dataset
def augment(image, label):
  image = tf.image.random_hue(image=image, max_delta=0.5, seed=42)
  image = tf.image.random_brightness(image=image, max_delta=0.2, seed=42)
  image = tf.image.random_flip_left_right(image=image, seed=42)
  return image, label

# %%
# applying the function on training set
train_ds = train_ds.map(augment)

# %%
# building input pipeline
train_ds = train_ds.shuffle(len(train_ds)).batch(32).cache().prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(32).cache().prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
# model building
model = Sequential([
    layers.Input(shape=(256, 256, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.SpatialDropout2D(rate=.2),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(num_cls, activation='softmax')
])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 128, 128, 16)     0
#  ropout2D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 32)                4194336
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 4,200,037
# Trainable params: 4,200,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model config
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# model training
history = model.fit(train_ds, validation_data=val_ds, epochs=2, verbose=1)
# Out:
# Epoch 1/2
# 92/92 [==============================] - 23s 74ms/step - loss: 1.7384 - accuracy: 0.2238 - val_loss: 1.5886 - val_accuracy: 0.2480
# Epoch 2/2
# 92/92 [==============================] - 4s 43ms/step - loss: 1.5379 - accuracy: 0.3031 - val_loss: 1.5319 - val_accuracy: 0.3134

# %%
# model accuracy
scores = model.evaluate(test_ds, verbose=0)
print('Accuracy:', round(scores[1] * 100, 2))
# Out:
# Accuracy: 30.25

# %%
# model accuracy evaluation
plt.figure(figsize=(5,3))
plt.plot(history.history['accuracy'], label='training')
plt.plot(history.history['val_accuracy'], label='validation')
plt.title('Accuracy Evaluation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

# %%
# model loss evaluation
plt.figure(figsize=(5,3))
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Loss Evaluation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();
